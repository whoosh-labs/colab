# %% [markdown]
# ## 🪄 Install `raga-testing-platform` library

# %%
pip install -U raga-testing-platform

# %% [markdown]
# ### Put your `ACCESS KEY & SECRET KEY`

# %%
# Define the access key, secret key, and host
ACCESS_KEY = "Paste_your_access_key_here"
SECRET_KEY = "Paste_your_secret_key_here"
HOST = "http://13.126.220.245:8080/"

# %% [markdown]
# ### Import All raga lib from raga module

# %%
from raga import *
import datetime

# %% [markdown]
# ### 🪄 Set up a Run

# %%
project_name = "Object Detection"
run_name = f"Demo-Run-{datetime.datetime.now().strftime('%Y%m%d%H%M%S')}"
test_session = TestSession(project_name=project_name,run_name=run_name, access_key=ACCESS_KEY, secret_key=SECRET_KEY, host=HOST)

# %% [markdown]
# ### 👟 Run Drift ROI

# %%
rules = DriftDetectionRules()
rules.add(type="multi_class_anomaly_detection", dist_metric="Mahalanobis", _class="ALL")

edge_case_detection = data_drift_detection(test_session=test_session,
                                           test_name="Drift-detection-test",
                                           train_dataset_name="drift_honeywell_all_gt_object_detection",
                                           field_dataset_name="drift_honeywell_traffic_pred_object_detection_v1",
                                           train_embed_col_name="ImageVectorsM1",
                                           field_embed_col_name = "ImageVectorsM1",
                                           output_type = "object_detection",
                                           level = "roi",
                                           rules = rules)


test_session.add(edge_case_detection)

test_session.run()

# %%
rules = DriftDetectionRules()
rules.add(type="multi_class_anomaly_detection", dist_metric="Mahalanobis", _class="ALL")

edge_case_detection = data_drift_detection(test_session=test_session,
                                           test_name="Drift-detection-test",
                                           train_dataset_name="drift_honeywell_all_gt_object_detection",
                                           field_dataset_name="drift_honeywell_vaccination_pred_object_detection_v2",
                                           train_embed_col_name="ImageVectorsM1",
                                           field_embed_col_name = "ImageVectorsM1",
                                           output_type = "object_detection",
                                           level = "roi",
                                           rules = rules)


test_session.add(edge_case_detection)

test_session.run()

# %% [markdown]
# ### 👟 Run Outlier ROI

# %%
rules = DriftDetectionRules()
rules.add(type="anomaly_detection", dist_metric="Mahalanobis", _class="ALL", threshold=21.3)
edge_case_detection = data_drift_detection(test_session=test_session,
                                           test_name="Drift-detection-HW",
                                           dataset_name="drift_honeywell_traffic_pred_object_detection_v1",
                                           embed_col_name = "ImageVectorsM1",
                                           output_type = "outlier_detection",
                                           rules = rules)
test_session.add(edge_case_detection)

test_session.run()

# %%
rules = DriftDetectionRules()
rules.add(type="anomaly_detection", dist_metric="Mahalanobis", _class="ALL", threshold=21.3)
edge_case_detection = data_drift_detection(test_session=test_session,
                                           test_name="Drift-detection-HW",
                                           dataset_name="drift_honeywell_vaccination_pred_object_detection_v2",
                                           embed_col_name = "ImageVectorsM1",
                                           output_type = "outlier_detection",
                                           rules = rules)
test_session.add(edge_case_detection)

test_session.run()

# %% [markdown]
# Please switch to http://13.126.220.245:3000/projects
