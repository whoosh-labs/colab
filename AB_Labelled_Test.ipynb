# %% [markdown]
# ### Install raga-testing-platform using pip

# %%
pip install raga-testing-platform==1.0.32
# Out:
# Requirement already satisfied: raga-testing-platform==1.0.32 in /usr/local/lib/python3.10/dist-packages (1.0.32)
# Requirement already satisfied: pandas==2.0.2 in /usr/local/lib/python3.10/dist-packages (from raga-testing-platform==1.0.32) (2.0.2)
# Requirement already satisfied: urllib3==1.26.7 in /usr/local/lib/python3.10/dist-packages (from raga-testing-platform==1.0.32) (1.26.7)
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.10/dist-packages (from raga-testing-platform==1.0.32) (2.31.0)
# Requirement already satisfied: numpy==1.24.3 in /usr/local/lib/python3.10/dist-packages (from raga-testing-platform==1.0.32) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.2->raga-testing-platform==1.0.32) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.2->raga-testing-platform==1.0.32) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.2->raga-testing-platform==1.0.32) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->raga-testing-platform==1.0.32) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->raga-testing-platform==1.0.32) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->raga-testing-platform==1.0.32) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas==2.0.2->raga-testing-platform==1.0.32) (1.16.0)

# %% [markdown]
# ### Create .raga dir for raga config

# %%
# !mkdir /root/.raga

# %% [markdown]
# ### Create /root/.raga/config file and put configs

# %%
# !touch /root/.raga/config
# !echo -e "[default]\nraga_access_key_id=bU9KZp8KHMWziEs9i89Y\nraga_secret_access_key=R3cH9iQaDB0WAIR7Nnhs9VoT1pv3Z9mStivTLM7g\napi_host=http://65.0.13.122:8080/" > /root/.raga/config

# %% [markdown]
# ### Verify Config file values

# %%
# !cat /root/.raga/config
# Out:
# [default]
# raga_access_key_id=bU9KZp8KHMWziEs9i89Y
# raga_secret_access_key=R3cH9iQaDB0WAIR7Nnhs9VoT1pv3Z9mStivTLM7g
# api_host=http://65.0.13.122:8080/

# %% [markdown]
# ### Import All raga lib from raga module

# %%
from raga import *

# %%
import os
os.environ["DEBUG"]="1"

# %% [markdown]
# ### Asign Project Name, Run Name and Dataset Name

# %%
project_name = "testingProject"
run_name = "colab-test-07_Aug_K_02"
dataset_name = "k_pd_dataset_07_aug_v01"

# %% [markdown]
# ### Create `TestSession` Object to connect with backend server
# Make sure `run_name` should be unique whenevere you run `TestSession` object

# %%
test_session = TestSession(project_name=project_name,run_name=run_name)
# Out:
# Access token generated successfully
# Project fetched successfully
# Experiment created successfully

# %% [markdown]
# ### Assign Variables to run AB Test

# %%
testName = StringElement("QA_Labelled_04Jul_02")
modelA = StringElement("modelA")
modelB = StringElement("modelB")
gt = StringElement("modelGT")
type = ModelABTestTypeElement("labelled")
aggregation_level = AggregationLevelElement()
aggregation_level.add(StringElement("Reflection"))
aggregation_level.add(StringElement("Overlap"))
aggregation_level.add(StringElement("CameraAngle"))
rules = ModelABTestRules()
rules.add(metric = StringElement("precision_diff_all"), IoU = FloatElement(0.5), _class = StringElement("ALL"), threshold = FloatElement(0.5))
rules.add(metric = StringElement("precision_candy"), IoU = FloatElement(0.5), _class = StringElement("candy"), threshold = FloatElement(0.5))

# %% [markdown]
# ### Create map of ab test

# %%
model_comparison_check = model_ab_test(test_session, dataset_name=dataset_name, testName=testName, modelA = modelA , modelB = modelB , type = type,  rules = rules, gt=gt)
# Out:
# Dataset fetched successfully

# %% [markdown]
# ### Add AB Test maps into list

# %%
test_session.add(model_comparison_check)

# %% [markdown]
# ### Now run every test

# %%
test_session.run()
# Out:
# Test created successfully
# abtest-labelled "{\"orgId\":\"1\",\"dataSet\":\"k_pd_dataset_07_aug_v01\",\"modelAInferenceCol\":\"inference_1\",\"modelBInferenceCol\":\"inference_2\",\"aggregationColumns\":[],\"parameter\":{\"parameterItems\":[{\"threshold\":0.5,\"metricColumnName\":\"metrics_labelled_ab_1_2_1126_2499\",\"iou\":0.5,\"preSignedUrl\":\"https://ragamediatest.s3.ap-south-1.amazonaws.com/1/testingProject/colab-test-07_Aug_K_02/2499/result.json?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20230807T063733Z&X-Amz-SignedHeaders=content-type%3Bhost&X-Amz-Expires=43200&X-Amz-Credential=AKIAYV3U7TVAZMCJSWU7%2F20230807%2Fap-south-1%2Fs3%2Faws4_request&X-Amz-Signature=c0709c55dde037d12f62fa1325d866781451f9349c854513a590355cf39c7a0e\",\"clazz\":[\"ALL\"]},{\"threshold\":0.5,\"metricColumnName\":\"metrics_labelled_ab_1_2_1126_2500\",\"iou\":0.5,\"preSignedUrl\":\"https://ragamediatest.s3.ap-south-1.amazonaws.com/1/testingProject/colab-test-07_Aug_K_02/2500/result.json?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20230807T063733Z&X-Amz-SignedHeaders=content-type%3Bhost&X-Amz-Expires=43200&X-Amz-Credential=AKIAYV3U7TVAZMCJSWU7%2F20230807%2Fap-south-1%2Fs3%2Faws4_request&X-Amz-Signature=e204ae05d9e30d4968bac14472bfacfc06b64baf41650d1a919ef59195728f3c\",\"clazz\":[\"candy\"]}]},\"groundTruthInferenceCol\":\"inference_3\"}"
