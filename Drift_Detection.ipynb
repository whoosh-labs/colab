# %% [markdown]
# ### Install raga-testing-platform using pip

# %%
pip install raga-testing-platform==1.0.32
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting raga-testing-platform==1.0.32
#   Downloading raga_testing_platform-1.0.32-py3-none-any.whl (638 kB)
#      |████████████████████████████████| 638 kB 1.0 MB/s eta 0:00:01
# Collecting urllib3==1.26.7
#   Using cached urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
# Collecting pandas==2.0.2
#   Using cached pandas-2.0.2-cp39-cp39-macosx_11_0_arm64.whl (10.9 MB)
# Collecting requests==2.31.0
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting numpy==1.24.3
#   Using cached numpy-1.24.3-cp39-cp39-macosx_11_0_arm64.whl (13.9 MB)
# Collecting tzdata>=2022.1
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/manabroy/Library/Python/3.9/lib/python/site-packages (from pandas==2.0.2->raga-testing-platform==1.0.32) (2.8.2)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#      |████████████████████████████████| 158 kB 1.1 MB/s eta 0:00:01
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.2.0-cp39-cp39-macosx_11_0_arm64.whl (124 kB)
#      |████████████████████████████████| 124 kB 1.1 MB/s eta 0:00:01
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Requirement already satisfied: six>=1.5 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas==2.0.2->raga-testing-platform==1.0.32) (1.15.0)
# Installing collected packages: urllib3, tzdata, pytz, numpy, idna, charset-normalizer, certifi, requests, pandas, raga-testing-platform
# Successfully installed certifi-2023.7.22 charset-normalizer-3.2.0 idna-3.4 numpy-1.24.3 pandas-2.0.2 pytz-2023.3 raga-testing-platform-1.0.32 requests-2.31.0 tzdata-2023.3 urllib3-1.26.7
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Create .raga dir for raga config

# %%
# !mkdir /root/.raga
# Out:
# mkdir: /root: No such file or directory

# %% [markdown]
# ### Create /root/.raga/config file and put configs

# %%
# !touch /root/.raga/config
# !echo -e "[default]\nraga_access_key_id=tCumelJ4d0FCOjSj1ROa\nraga_secret_access_key=jdecb6CDkHxphb5NduRrlra9mG0R3mtqmYcYmU0i\napi_host=http://65.0.13.122:8080/" > /root/.raga/config
# Out:
# touch: /root/.raga/config: No such file or directory
# zsh:1: no such file or directory: /root/.raga/config

# %% [markdown]
# ### Verify Config file values

# %%
# !cat /root/.raga/config
# Out:
# cat: /root/.raga/config: No such file or directory

# %% [markdown]
# ### Import All raga lib from raga module

# %%
from raga import *

# %% [markdown]
# ### Asign Project Name, Run Name and Dataset Name

# %% [markdown]
# Dataset name and Embedding column name is different for image level and roi level

# %%
project_name = "Video Surveillance"
run_name = "colab-test-DriftIMG-V1_7Aug"
dataset_name_train = "k_drift_trainds_07Aug_V01ROI"
dataset_name_field = "k_drift_fieldds_07Aug_V01ROI"
#dataset_name_train = "k_drift_trainds_31jul_V01ROI"
#dataset_name_field = "k_drift_fieldds_31jul_V01ROI"
# train_embed_col_name = f'ImageVectors Train' #Train dataset embedding column name
# field_embed_col_name = f'ImageVectors Field' #Field dataset embedding column name
train_embed_col_name = f'ROIVectors Train' #Train dataset embedding column name
field_embed_col_name = f'ROIVectors Field' #Field dataset embedding column name

# %% [markdown]
# ### Create `TestSession` Object to connect with backend server
# Make sure `run_name` should be unique whenevere you run `TestSession` object

# %%
test_session = TestSession(project_name=project_name,run_name=run_name)
# Out:
# Access token generated successfully
# Value error occurred: Request failed with status code 404: Project does not exists with name : Video Surveillance
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/raga/test_session.py:39, in TestSession.initialize(self)
#      38 self.token = self.create_token()
# ---> 39 self.project_id = self.get_project_id()
#      40 self.experiment_id = self.create_experiment()
#
# File ~/Library/Python/3.9/lib/python/site-packages/raga/test_session.py:140, in TestSession.get_project_id(self)
#     130 """
#     131 Get project id by sending a request to the Raga API.
#     132
#    (...)
#     138     ValueError: If the response data is not in the expected format.
#     139 """
# --> 140 res_data = self.http_client.get(
#     141     "api/project",
#     142     params={"name": self.project_name},
#     143     headers={"Authorization": f'Bearer {self.token}'},
#     144 )
#     146 if not isinstance(res_data, dict):
#
# File ~/Library/Python/3.9/lib/python/site-packages/raga/utils/http_client.py:74, in HTTPClient.get(self, endpoint, params, data, headers)
#      73 if error_message:
# ---> 74     raise ValueError(f"Request failed with status code {status_code}: {error_message}")
#      75 else:
#
# ValueError: Request failed with status code 404: Project does not exists with name : Video Surveillance
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[7], line 1
# ----> 1 test_session = TestSession(project_name=project_name,run_name=run_name)
#
# File ~/Library/Python/3.9/lib/python/site-packages/raga/test_session.py:31, in TestSession.__init__(self, project_name, run_name, u_test)
#      30 if not u_test:
# ---> 31     self.initialize()
#
# File ~/Library/Python/3.9/lib/python/site-packages/raga/test_session.py:53, in TestSession.initialize(self)
#      52     print(f"Value error occurred: {str(exception)}")
# ---> 53     sys.exit() # No need to retry if a ValueError occurs
#      54 except Exception as exception:
#
# SystemExit:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:2095, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2092 if exception_only:
#    2093     stb = ['An exception has occurred, use %tb to see '
#    2094            'the full traceback.\n']
# -> 2095     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2096                                                      value))
#    2097 else:
#    2098     try:
#    2099         # Exception classes can customise their traceback - we
#    2100         # use this in IPython.parallel for exceptions occurring
#    2101         # in the engines. This should return a list of strings.
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/ultratb.py:1428, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1426 else:
#    1427     self.tb = etb
# -> 1428 return FormattedTB.structured_traceback(
#    1429     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1430 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/ultratb.py:1319, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1316 mode = self.mode
#    1317 if mode in self.verbose_modes:
#    1318     # Verbose modes need a full traceback
# -> 1319     return VerboseTB.structured_traceback(
#    1320         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1321     )
#    1322 elif mode == 'Minimal':
#    1323     return ListTB.get_exception_only(self, etype, value)
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/ultratb.py:1172, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1163 def structured_traceback(
#    1164     self,
#    1165     etype: type,
#    (...)
#    1169     number_of_lines_of_context: int = 5,
#    1170 ):
#    1171     """Return a nice text document describing the traceback."""
# -> 1172     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1173                                                            tb_offset)
#    1175     colors = self.Colors  # just a shorthand + quicker name lookup
#    1176     colorsnormal = colors.Normal  # used a lot
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/ultratb.py:1062, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1059 assert isinstance(tb_offset, int)
#    1060 head = self.prepare_header(str(etype), self.long_header)
#    1061 records = (
# -> 1062     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1063 )
#    1065 frames = []
#    1066 skipped = 0
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/ultratb.py:1130, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1128 while cf is not None:
#    1129     try:
# -> 1130         mod = inspect.getmodule(cf.tb_frame)
#    1131         if mod is not None:
#    1132             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'

# %% [markdown]
# ### Assign Variables to run AB Test

# %% [markdown]
# For different level embedding column name is different , use accordingly

# %%
testName = StringElement("test-labelled-3Aug23_v11")
train_dataset_name = StringElement("k_drift_trainds_03Aug_V03ROI")
field_dataset_name = StringElement("k_drift_fieldds_03Aug_V03ROI")
# train_embed_col_name = StringElement("ImageVectors Train")  #for train col in image level
# field_embed_col_name = StringElement("ImageVectors Field")  #for field col in image level
# level = StringElement("image")
train_embed_col_name = StringElement("ROIVectors Train")      #for train col in roi level
field_embed_col_name = StringElement("ROIVectors Field")      #for field col in roi level
level = StringElement("roi")
aggregation_level = AggregationLevelElement()
aggregation_level.add(StringElement("Reflection"))
aggregation_level.add(StringElement("Overlap"))
aggregation_level.add(StringElement("CameraAngle"))
rules = DriftDetectionRules()
rules.add(type=StringElement("anomaly_detection"), dist_metric=StringElement("Euclidian"), _class = StringElement("ALL"), threshold = FloatElement(0.5))

# %% [markdown]
# ### Create map of ab test

# %%
edge_case_detection = data_drift_detection(test_session, testName=testName, train_dataset_name=train_dataset_name, field_dataset_name=field_dataset_name, train_embed_col_name=train_embed_col_name, field_embed_col_name = field_embed_col_name , level = level, aggregation_level=aggregation_level, rules = rules)

# %% [markdown]
# ### Add AB Test maps into list

# %%
test_session.add(edge_case_detection)

# %% [markdown]
# ### Now run every test

# %%
test_session.run()
