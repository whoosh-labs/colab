# %% [markdown]
# ### Install raga-testing-platform using pip

# %%
pip install raga-testing-platform==1.0.32
# Out:
# Collecting raga-testing-platform==1.0.32
#   Downloading raga_testing_platform-1.0.32-py3-none-any.whl (638 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 638.4/638.4 kB 5.9 MB/s eta 0:00:00
# Collecting pandas==2.0.2 (from raga-testing-platform==1.0.32)
#   Downloading pandas-2.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 43.5 MB/s eta 0:00:00
# Collecting urllib3==1.26.7 (from raga-testing-platform==1.0.32)
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.8/138.8 kB 12.6 MB/s eta 0:00:00
# Collecting requests==2.31.0 (from raga-testing-platform==1.0.32)
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 4.1 MB/s eta 0:00:00
# Collecting numpy==1.24.3 (from raga-testing-platform==1.0.32)
#   Downloading numpy-1.24.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 43.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.2->raga-testing-platform==1.0.32) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.2->raga-testing-platform==1.0.32) (2022.7.1)
# Collecting tzdata>=2022.1 (from pandas==2.0.2->raga-testing-platform==1.0.32)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 24.7 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->raga-testing-platform==1.0.32) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->raga-testing-platform==1.0.32) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->raga-testing-platform==1.0.32) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas==2.0.2->raga-testing-platform==1.0.32) (1.16.0)
# Installing collected packages: urllib3, tzdata, numpy, requests, pandas, raga-testing-platform
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.16
#     Uninstalling urllib3-1.26.16:
#       Successfully uninstalled urllib3-1.26.16
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Uninstalling requests-2.27.1:
#       Successfully uninstalled requests-2.27.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.0.2 which is incompatible.
# google-colab 1.0.0 requires requests==2.27.1, but you have requests 2.31.0 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.3 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.24.3 which is incompatible.
# Successfully installed numpy-1.24.3 pandas-2.0.2 raga-testing-platform-1.0.32 requests-2.31.0 tzdata-2023.3 urllib3-1.26.7

# %% [markdown]
# ### Create .raga dir for raga config

# %%
# !mkdir /root/.raga
# Out:
# mkdir: cannot create directory ‘/root/.raga’: File exists

# %% [markdown]
# ### Create /root/.raga/config file and put configs

# %%
# !touch /root/.raga/config
# !echo -e "[default]\nraga_access_key_id=tCumelJ4d0FCOjSj1ROa\nraga_secret_access_key=jdecb6CDkHxphb5NduRrlra9mG0R3mtqmYcYmU0i\napi_host=http://65.0.13.122:8080/" > /root/.raga/config

# %% [markdown]
# ### Verify Config file values

# %%
# !cat /root/.raga/config
# Out:
# [default]
# raga_access_key_id=tCumelJ4d0FCOjSj1ROa
# raga_secret_access_key=jdecb6CDkHxphb5NduRrlra9mG0R3mtqmYcYmU0i
# api_host=http://65.0.13.122:8080/

# %% [markdown]
# ### Import All raga lib from raga module

# %%
from raga import *

# %% [markdown]
# ### Asign Project Name, Run Name and Dataset Name

# %% [markdown]
# Dataset name and Embedding column name is different for image level and roi level

# %%
project_name = "Video Surveillance"
run_name = "colab-test-DriftIMG-V1_7Aug"
dataset_name_train = "k_drift_trainds_07Aug_V01ROI"
dataset_name_field = "k_drift_fieldds_07Aug_V01ROI"
#dataset_name_train = "k_drift_trainds_31jul_V01ROI"
#dataset_name_field = "k_drift_fieldds_31jul_V01ROI"
# train_embed_col_name = f'ImageVectors Train' #Train dataset embedding column name
# field_embed_col_name = f'ImageVectors Field' #Field dataset embedding column name
train_embed_col_name = f'ROIVectors Train' #Train dataset embedding column name
field_embed_col_name = f'ROIVectors Field' #Field dataset embedding column name

# %% [markdown]
# ### Create `TestSession` Object to connect with backend server
# Make sure `run_name` should be unique whenevere you run `TestSession` object

# %%
test_session = TestSession(project_name=project_name,run_name=run_name)
# Out:
# Access token generated successfully
# Project fetched successfully
# Experiment created successfully

# %% [markdown]
# ### Assign Variables to run AB Test

# %% [markdown]
# For different level embedding column name is different , use accordingly

# %%
testName = StringElement("test-labelled-3Aug23_v11")
train_dataset_name = StringElement("k_drift_trainds_03Aug_V03ROI")
field_dataset_name = StringElement("k_drift_fieldds_03Aug_V03ROI")
# train_embed_col_name = StringElement("ImageVectors Train")  #for train col in image level
# field_embed_col_name = StringElement("ImageVectors Field")  #for field col in image level
# level = StringElement("image")
train_embed_col_name = StringElement("ROIVectors Train")      #for train col in roi level
field_embed_col_name = StringElement("ROIVectors Field")      #for field col in roi level
level = StringElement("roi")
aggregation_level = AggregationLevelElement()
aggregation_level.add(StringElement("Reflection"))
aggregation_level.add(StringElement("Overlap"))
aggregation_level.add(StringElement("CameraAngle"))
rules = DriftDetectionRules()
rules.add(type=StringElement("anomaly_detection"), dist_metric=StringElement("Euclidian"), _class = StringElement("ALL"), threshold = FloatElement(0.5))

# %% [markdown]
# ### Create map of ab test

# %%
edge_case_detection = data_drift_detection(test_session, testName=testName, train_dataset_name=train_dataset_name, field_dataset_name=field_dataset_name, train_embed_col_name=train_embed_col_name, field_embed_col_name = field_embed_col_name , level = level, aggregation_level=aggregation_level, rules = rules)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-ec86bc9bd06e> in <cell line: 1>()
# ----> 1 edge_case_detection = data_drift_detection(test_session, testName=testName, train_dataset_name=train_dataset_name, field_dataset_name=field_dataset_name, train_embed_col_name=train_embed_col_name, field_embed_col_name = field_embed_col_name , level = level, aggregation_level=aggregation_level, rules = rules)
#
# /usr/local/lib/python3.10/dist-packages/raga/post_deployment_checks.py in data_drift_detection(test_session, train_dataset_name, field_dataset_name, testName, train_embed_col_name, field_embed_col_name, level, rules, aggregation_level, filter)
#       5 filter: Optional[StringElement] = StringElement("")):
#       6
# ----> 7     train_dataset_id, field_dataset_id = data_drift_detection_validation(test_session=test_session, train_dataset_name=train_dataset_name, field_dataset_name=field_dataset_name, testName=testName, train_embed_col_name=train_embed_col_name, field_embed_col_name=field_embed_col_name, level=level, rules=rules)
#       8     response = {
#       9             "datasetId": field_dataset_id,
#
# /usr/local/lib/python3.10/dist-packages/raga/post_deployment_checks.py in data_drift_detection_validation(test_session, train_dataset_name, field_dataset_name, testName, train_embed_col_name, field_embed_col_name, level, rules)
#      29     assert isinstance(field_dataset_name, StringElement) and field_dataset_name.get(), "field_dataset_name is required and must be an instance of the StringElement class."
#      30
# ---> 31     train_res_data = test_session.http_client.get(f"api/dataset?projectId={test_session.project_id}&name={train_dataset_name.get()}", headers={"Authorization": f'Bearer {test_session.token}'})
#      32     if not isinstance(train_res_data, dict):
#      33             raise ValueError("Invalid response data. Expected a dictionary.")
#
# /usr/local/lib/python3.10/dist-packages/raga/utils/http_client.py in get(self, endpoint, params, data, headers)
#      72             error_message = json_data.get("message")
#      73             if error_message:
# ---> 74                 raise ValueError(f"Request failed with status code {status_code}: {error_message}")
#      75             else:
#      76                 raise ValueError(f"Request failed with status code {status_code}")
#
# ValueError: Request failed with status code 404: Dataset does not exists with Name : k_drift_trainds_03Aug_V03ROI

# %% [markdown]
# ### Add AB Test maps into list

# %%
test_session.add(edge_case_detection)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ce2d113b883b> in <cell line: 1>()
# ----> 1 test_session.add(edge_case_detection)
#
# NameError: name 'edge_case_detection' is not defined

# %% [markdown]
# ### Now run every test

# %%
test_session.run()
# Out:
# Test created successfully
# ood "{\"orgId\":\"1\",\"dataSet\":\"k_drift_fieldds_03aug_v03roi\",\"aggregationColumns\":[\"attribute_2\",\"attribute_1\",\"attribute_3\"],\"level\":\"roi\",\"parameter\":{\"parameterItems\":[{\"type\":\"anomaly_detection\",\"threshold\":0.5,\"metricColumnName\":\"metrics_drift_1125_2498\",\"distMetric\":\"Euclidian\",\"preSignedUrl\":\"https://ragamediatest.s3.ap-south-1.amazonaws.com/1/testingProject/colab-test-DriftIMG-V1_7Aug/2498/result.json?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20230807T060719Z&X-Amz-SignedHeaders=content-type%3Bhost&X-Amz-Expires=43200&X-Amz-Credential=AKIAYV3U7TVAZMCJSWU7%2F20230807%2Fap-south-1%2Fs3%2Faws4_request&X-Amz-Signature=56e4012d0d1129c86543900c0d33d96c68c59d25b0a4706920d586e9f3e59d01\",\"clazz\":[\"ALL\"]}]},\"trainDataset\":\"k_drift_trainds_03aug_v03roi\",\"trainDSEmbeddingCol\":\"roiEmbedding_1\",\"testDSEmbeddingCol\":\"roiEmbedding_1\"}"
