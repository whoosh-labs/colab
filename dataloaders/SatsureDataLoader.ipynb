# %% [markdown]
# ## 🪄 Install `raga-testing-platform` library

# %%
pip install -U raga-testing-platform
# Out:
# Requirement already satisfied: raga-testing-platform in /Users/manabroy/Downloads/colab/.venv/lib/python3.10/site-packages (1.1.21)
# Collecting raga-testing-platform
#   Downloading raga_testing_platform-1.1.22-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pandas==2.0.2 in /Users/manabroy/Downloads/colab/.venv/lib/python3.10/site-packages (from raga-testing-platform) (2.0.2)
# Requirement already satisfied: urllib3==1.26.7 in /Users/manabroy/Downloads/colab/.venv/lib/python3.10/site-packages (from raga-testing-platform) (1.26.7)
# Requirement already satisfied: requests==2.31.0 in /Users/manabroy/Downloads/colab/.venv/lib/python3.10/site-packages (from raga-testing-platform) (2.31.0)
# Requirement already satisfied: numpy==1.24.3 in /Users/manabroy/Downloads/colab/.venv/lib/python3.10/site-packages (from raga-testing-platform) (1.24.3)
# Requirement already satisfied: halo==0.0.31 in /Users/manabroy/Downloads/colab/.venv/lib/python3.10/site-packages (from raga-testing-platform) (0.0.31)
# Requirement already satisfied: log-symbols>=0.0.14 in /Users/manabroy/Downloads/colab/.venv/lib/python3.10/site-packages (from halo==0.0.31->raga-testing-platform) (0.0.14)
# Requirement already satisfied: spinners>=0.0.24 in /Users/manabroy/Downloads/colab/.venv/lib/python3.10/site-packages (from halo==0.0.31->raga-testing-platform) (0.0.24)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/manabroy/Downloads/colab/.venv/lib/python3.10/site-packages (from halo==0.0.31->raga-testing-platform) (2.3.0)
# Requirement already satisfied: colorama>=0.3.9 in /Users/manabroy/Downloads/colab/.venv/lib/python3.10/site-packages (from halo==0.0.31->raga-testing-platform) (0.4.6)
# Requirement already satisfied: six>=1.12.0 in /Users/manabroy/Downloads/colab/.venv/lib/python3.10/site-packages (from halo==0.0.31->raga-testing-platform) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/manabroy/Downloads/colab/.venv/lib/python3.10/site-packages (from pandas==2.0.2->raga-testing-platform) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/manabroy/Downloads/colab/.venv/lib/python3.10/site-packages (from pandas==2.0.2->raga-testing-platform) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/manabroy/Downloads/colab/.venv/lib/python3.10/site-packages (from pandas==2.0.2->raga-testing-platform) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/manabroy/Downloads/colab/.venv/lib/python3.10/site-packages (from requests==2.31.0->raga-testing-platform) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/manabroy/Downloads/colab/.venv/lib/python3.10/site-packages (from requests==2.31.0->raga-testing-platform) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/manabroy/Downloads/colab/.venv/lib/python3.10/site-packages (from requests==2.31.0->raga-testing-platform) (2023.11.17)
# Downloading raga_testing_platform-1.1.22-py3-none-any.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 990.8 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: raga-testing-platform
#   Attempting uninstall: raga-testing-platform
#     Found existing installation: raga-testing-platform 1.1.21
#     Uninstalling raga-testing-platform-1.1.21:
#       Successfully uninstalled raga-testing-platform-1.1.21
# Successfully installed raga-testing-platform-1.1.22
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Put your `ACCESS KEY & SECRET KEY`

# %%
# Define the access key, secret key, and host
ACCESS_KEY = "LGXJjQFD899MtVSrNHGH  "
SECRET_KEY = "TC466Qu9PhpOjTuLu5aGkXyGbM7SSBeAzYH6HpcP"
HOST = "http://3.111.106.226:8080"

# %% [markdown]
# ### Import All raga lib from raga module

# %%
from raga import *
import datetime
# Out:
# Error in callback <function Halo.__init__.<locals>.clean_up at 0x105c353f0> (for post_run_cell), with arguments args (<ExecutionResult object at 105b4f4f0, execution_count=3 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 105b4f250, raw_cell="from raga import *
# import datetime" store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/Users/manabroy/Downloads/colab/dataloaders/SatsureDataLoader.ipynb#W5sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: Halo.__init__.<locals>.clean_up() takes 0 positional arguments but 1 was given

# %% [markdown]
# ### 🪄 Set up a Run

# %%
project_name = "testingProject"
run_name = f"Demo-Run-{datetime.datetime.now().strftime('%Y%m%d%H%M%S')}"
test_session = TestSession(project_name=project_name,run_name=run_name, access_key=ACCESS_KEY, secret_key=SECRET_KEY, host=HOST)
