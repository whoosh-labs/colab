# %% [markdown]
# ## 🪄 Install `raga-testing-platform` library

# %%
pip install -U raga-testing-platform
# Out:
# Collecting raga-testing-platform
#   Downloading raga_testing_platform-1.1.21-py3-none-any.whl.metadata (3.3 kB)
# Collecting pandas==2.0.2 (from raga-testing-platform)
#   Downloading pandas-2.0.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting urllib3==1.26.7 (from raga-testing-platform)
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.8/138.8 kB 917.0 kB/s eta 0:00:00 kB/s eta 0:00:01
# Collecting requests==2.31.0 (from raga-testing-platform)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting numpy==1.24.3 (from raga-testing-platform)
#   Downloading numpy-1.24.3-cp310-cp310-macosx_11_0_arm64.whl (13.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 11.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting halo==0.0.31 (from raga-testing-platform)
#   Downloading halo-0.0.31.tar.gz (11 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting log-symbols>=0.0.14 (from halo==0.0.31->raga-testing-platform)
#   Downloading log_symbols-0.0.14-py3-none-any.whl (3.1 kB)
# Collecting spinners>=0.0.24 (from halo==0.0.31->raga-testing-platform)
#   Downloading spinners-0.0.24-py3-none-any.whl (5.5 kB)
# Collecting termcolor>=1.1.0 (from halo==0.0.31->raga-testing-platform)
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting colorama>=0.3.9 (from halo==0.0.31->raga-testing-platform)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: six>=1.12.0 in ./.venv/lib/python3.10/site-packages (from halo==0.0.31->raga-testing-platform) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.10/site-packages (from pandas==2.0.2->raga-testing-platform) (2.8.2)
# Collecting pytz>=2020.1 (from pandas==2.0.2->raga-testing-platform)
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas==2.0.2->raga-testing-platform)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 10.5 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2 (from requests==2.31.0->raga-testing-platform)
#   Downloading charset_normalizer-3.3.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests==2.31.0->raga-testing-platform)
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting certifi>=2017.4.17 (from requests==2.31.0->raga-testing-platform)
#   Using cached certifi-2023.11.17-py3-none-any.whl.metadata (2.2 kB)
# Downloading raga_testing_platform-1.1.21-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.4/101.4 kB 4.3 MB/s eta 0:00:00
# Downloading pandas-2.0.2-cp310-cp310-macosx_11_0_arm64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 5.4 MB/s eta 0:00:00m eta 0:00:010:0101m
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached certifi-2023.11.17-py3-none-any.whl (162 kB)
# Downloading charset_normalizer-3.3.2-cp310-cp310-macosx_11_0_arm64.whl (120 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.4/120.4 kB 4.7 MB/s eta 0:00:00
# Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.5/502.5 kB 9.7 MB/s eta 0:00:006 MB/s eta 0:00:01
# Building wheels for collected packages: halo
#   Building wheel for halo (pyproject.toml) ... done
#   Created wheel for halo: filename=halo-0.0.31-py3-none-any.whl size=11234 sha256=8ddfc52a6c75d1ac14138370fdec2387820f5cf0250901811e139713a2fd78ba
#   Stored in directory: /Users/manabroy/Library/Caches/pip/wheels/5a/d9/8a/b4f14c44aba7c164d4379eca6f1dde59360050406b1edaec24
# Successfully built halo
# Installing collected packages: spinners, pytz, urllib3, tzdata, termcolor, numpy, idna, colorama, charset-normalizer, certifi, requests, pandas, log-symbols, halo, raga-testing-platform
# Successfully installed certifi-2023.11.17 charset-normalizer-3.3.2 colorama-0.4.6 halo-0.0.31 idna-3.4 log-symbols-0.0.14 numpy-1.24.3 pandas-2.0.2 pytz-2023.3.post1 raga-testing-platform-1.1.21 requests-2.31.0 spinners-0.0.24 termcolor-2.3.0 tzdata-2023.3 urllib3-1.26.7
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Put your `ACCESS KEY & SECRET KEY`

# %%
# Define the access key, secret key, and host
ACCESS_KEY = "zjpK0OKpQJ2dk6n4zQUh"
SECRET_KEY = "4fFgIUKOJ2bjFJQ4mUVJEJYBiJr84G3MWESs5fO6"
HOST = "https://backend.raga-xai.satsure.co"

# %% [markdown]
# ### Import All raga lib from raga module

# %%
from raga import *
import datetime

# %% [markdown]
# ### 🪄 Set up a Run

# %%
project_name = "testingProject"
run_name = f"Demo-Run-{datetime.datetime.now().strftime('%Y%m%d%H%M%S')}"
test_session = TestSession(project_name=project_name,run_name=run_name, access_key=ACCESS_KEY, secret_key=SECRET_KEY, host=HOST)
